# %%
import pandas as pd
import numpy as np
from pyaemet import utilities as utl

# %%
HOME = "/home/jaimedgp/Repositories/covidIncidence-AirQuality/"

# %%
country = "Spain"

eea_country = "+".join(country.split(" "))

eea_url = ("http://aided.apps.eea.europa.eu/tools/download?download_query=http"
           + "%3A%2F%2Faided.apps.eea.europa.eu%2F%3Fsource%3D%7B%22query%22%"
           + "3A%7B%22bool%22%3A%7B%22must%22%3A%5B%7B%22term%22%3A%7B%22Coun"
           + "tryOrTerritory%22%3A%22" + eea_country + "%22%7D%7D%5D%7D%7D%2C%"
           + "22display_type%22%3A%22tabular%22%7D&download_format=csv")

# %%
eea_sites = pd.read_csv(eea_url).rename(columns={"Latitude": "latitude",
                                                 "Longitude": "longitude",})

# EEA situa la estacion de San Nicolas de Las Palmas de Gran Canaria sobre el 
# mar. Se corrige la localizacion por las coordenadas reales
eea_sites.loc[eea_sites.EoICode == "ES2097A", 
              ["latitude", "longitude"]
              ] = [28.10272, -15.42118]

# %%
filter_sites = eea_sites[(eea_sites["StationType"] == "Background") &
                         ((eea_sites["StationArea"] == "Suburban") | 
                          (eea_sites["StationArea"] == "Urban"))
                         ].drop_duplicates(subset=['EoICode'])

# %%
duplicate = {"La Coruña": "A Coruña",
             "Alacant": "Alicante",
             "València": "Valencia",
             "Castelló": "Castellón",
             "Gerona": "Girona"
             }

location_sites = utl.get_site_address(filter_sites).replace(duplicate)

# %%
location_sites.head()
# Out:
#   CountryOrTerritory    Namespace               Network  \
# 0              Spain  ES.BDCA.AQD  CCAA Com. Valenciana
# 1              Spain  ES.BDCA.AQD  CCAA Com. Valenciana
# 2              Spain  ES.BDCA.AQD        CCAA Andalucía
# 3              Spain  ES.BDCA.AQD        CCAA Andalucía
# 4              Spain  ES.BDCA.AQD      CCAA Extremadura
#
#                                     ResponsibleParty TimeZone  \
# 0  CONSELLERIA DE AGRICULTURA, MEDIO AMBIENTE, CA...      UTC
# 1  CONSELLERIA DE AGRICULTURA, MEDIO AMBIENTE, CA...      UTC
# 2  CONSEJERIA DE AGRICULTURA, GANADERIA, PESCA Y ...      UTC
# 3  CONSEJERIA DE AGRICULTURA, GANADERIA, PESCA Y ...      UTC
# 4  CONSEJERIA DE MEDIO AMBIENTE Y RURAL, POLITICA...      UTC
#
#           StationName  EoICode StationType StationArea  \
# 0            BENIDORM  ES1675A  Background    Suburban
# 1  ELX-AGROALIMENTARI  ES1624A  Background    Suburban
# 2        EL BOTICARIO  ES1786A  Background    Suburban
# 3            EL EJIDO  ES1549A  Background       Urban
# 4             BADAJOZ  ES1601A  Background       Urban
#
#                               Pollutant  ...     MeasurementEquipment  \
# 0               Nitrogen monoxide (air)  ...                  Unknown
# 1  Benzo(a)anthracene in PM10 (aerosol)  ...                      NaN
# 2                           Ozone (air)  ...                  Unknown
# 3                        o-Xylene (air)  ...                      NaN
# 4                 Carbon monoxide (air)  ...  DASIBI 3008 CO analyser
#
#                              MeasurementMethod  SamplingEquipment  \
# 0                            Chemiluminescence                NaN
# 1                                          NaN                NaN
# 2                  Ultraviolet (UV) photometry                NaN
# 3                                          NaN                NaN
# 4  Non-dispersive infrared spectroscopy (NDIR)                NaN
#
#                               AnalyticalTechnique  \
# 0                                             NaN
# 1  Gas chromatography + mass spectrometry (GC-MS)
# 2                                             NaN
# 3  Gas chromatography + mass spectrometry (GC-MS)
# 4                                             NaN
#
#                                             envelope  District      City  \
# 0  http://cdr.eionet.europa.eu/es/eu/aqd/d/envxfin7q            Benidorm
# 1  http://cdr.eionet.europa.eu/es/eu/aqd/d/envxfin7q               Elche
# 2  http://cdr.eionet.europa.eu/es/eu/aqd/d/envxfin7q             Almería
# 3  http://cdr.eionet.europa.eu/es/eu/aqd/d/envxfin7q  El Ejido  El Ejido
# 4  http://cdr.eionet.europa.eu/es/eu/aqd/d/envxfin7q             Badajoz
#
#   Subregion                Region CountryCode
# 0  Alicante  Comunitat Valenciana         ESP
# 1  Alicante  Comunidad Valenciana         ESP
# 2   Almería             Andalucía         ESP
# 3   Almería             Andalucía         ESP
# 4   Badajoz           Extremadura         ESP
#
# [5 rows x 29 columns]

# %%
cities_names = {"Corrales de Buelna, Los": "Los Corrales de Buelna",
                "Pamplona/Iruña": "Pamplona",
                "Alicante/Alacant": "Alicante",
                "Elche/Elx": "Elche",
                "Ejido, El": "El Ejido",
                "Alcoy/Alcoi": "Alcoy",
                "Sagunto/Sagunt": "Sagunto",
                "Olite/Erriberri": "Olite",
                "Palma ": "Palma",
                "Coruña, A": "A Coruña",
                "Línea de la Concepción, La": "La Línea de la Concepción",
                "Hospitalet de Llobregat, L'": "l'Hospitalet de Llobregat",
                "Prat de Llobregat, El": "El Prat de Llobregat",
                "Vall d'Uixó, la": "La Vall d'Uixó",
                "Bisbal d'Empordà, La": "La Bisbal d'Empordà",
                "València": "Valencia",
                "Palmas de Gran Canaria, Las": "Las Palmas de Gran Canaria",
                "Agurain/Salvatierra": "Salvatierra",
                "Vilafranca/Villafranca del Cid": "Villafranca del Cid",
                "Altsasu/Alsasua": "Alsasua",
                "Castelló de la Plana": "Castellón",
                "Arboç, L'": "l'Arboç",
                "Donostia/San Sebastián": "San Sebastián",
                }

mun_population = pd.read_excel(HOME+"data/ine/pobmun20.xlsx",
                               skiprows=1).replace(cities_names)

# %%
info_sites = pd.merge(location_sites, 
                      mun_population[["NOMBRE", 
                                      "POB20"]
                                     ].rename(columns={"NOMBRE": "City"}),
                      left_on="City", right_on="City",
                      how="left"
                      )

# %%
info_sites[pd.isna(info_sites["POB20"])]
# Out:
# Empty DataFrame
# Columns: [CountryOrTerritory, Namespace, Network, ResponsibleParty, TimeZone, StationName, EoICode, StationType, StationArea, Pollutant, SamplingPointId, latitude, longitude, Altitudee, MeasurementRegime, OperationalActivityBegin, OperationalActivityEnd, Sample, SamplingProcess, MeasurementEquipment, MeasurementMethod, SamplingEquipment, AnalyticalTechnique, envelope, District, City, Subregion, Region, CountryCode, POB20]
# Index: []
#
# [0 rows x 30 columns]

# %%
info_sites.to_csv(HOME+"data/background-sub-urban-eea-stations.csv", 
                  index=False)
